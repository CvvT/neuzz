# %%
import angr
import sys

from angr.codenode import BlockNode
from angr.knowledge_plugins.functions.function import Function
from capstone.x86_const import X86_OP_REG, X86_OP_IMM

# %%
program = "test"
proj = angr.Project(program, load_options={"auto_load_libs": False})
main = proj.loader.find_symbol("main")
cfg = proj.analyses.CFGEmulated(context_sensitivity_level=0, starts=[main.rebased_addr], call_depth=0, normalize=True)
func = cfg.functions[main.rebased_addr]
graph = func.transition_graph
# Out:
# WARNING | 2019-02-27 19:09:43,419 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff88 has an unspecified value; Generating an unconstrained value of 4 bytes.
# WARNING | 2019-02-27 19:09:43,572 | angr.state_plugins.symbolic_memory | Memory address 0x7ffffffffff0000 has an unspecified value; Generating an unconstrained value of 8 bytes.
# WARNING | 2019-02-27 19:09:43,781 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff8c has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:43,835 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff8d has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:43,886 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff8e has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:43,941 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff8f has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:43,997 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff90 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,053 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff91 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,105 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff92 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,166 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff93 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,224 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff94 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,280 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff95 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,311 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff96 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,368 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff97 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,421 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff98 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,478 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff99 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,532 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff9a has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,588 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff9b has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,646 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff9c has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,706 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff9d has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,760 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff9e has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,815 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeff9f has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,871 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa0 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,926 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa1 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:44,981 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa2 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,033 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa3 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,090 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa4 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,145 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa5 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,201 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa6 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,257 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa7 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,312 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa8 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,369 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffa9 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,424 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffaa has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,475 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffab has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,541 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffac has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,595 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffad has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,653 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffae has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,706 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffaf has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,761 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb0 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,817 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb1 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,877 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb2 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,933 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb3 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:45,991 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb4 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,048 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb5 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,101 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb6 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,157 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb7 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,219 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb8 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,276 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffb9 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,337 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffba has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,393 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffbb has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,446 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffbc has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,501 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffbd has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,557 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffbe has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,614 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffbf has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,668 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc0 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,726 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc1 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,787 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc2 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,844 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc3 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,896 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc4 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:46,952 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc5 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,008 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc6 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,068 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc7 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,123 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc8 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,177 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffc9 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,236 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffca has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,305 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffcb has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,423 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffcc has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,477 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffcd has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,532 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffce has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,587 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffcf has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,641 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd0 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,695 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd1 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,748 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd2 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,804 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd3 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,858 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd4 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,925 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd5 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:47,983 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd6 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,043 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd7 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,100 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd8 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,155 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffd9 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,214 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffda has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,270 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffdb has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,327 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffdc has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,384 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffdd has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,443 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffde has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,502 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffdf has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,555 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe0 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,616 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe1 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,672 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe2 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,727 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe3 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,788 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe4 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,849 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe5 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,907 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe6 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:48,962 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe7 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:49,019 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe8 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:49,073 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffe9 has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:49,126 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffea has an unspecified value; Generating an unconstrained value of 1 bytes.
# WARNING | 2019-02-27 19:09:49,180 | angr.state_plugins.symbolic_memory | Memory address 0x7fffffffffeffeb has an unspecified value; Generating an unconstrained value of 1 bytes.

# %%
def get_node(nodes, addr, fuzzy=False):
    if fuzzy:
        for node in nodes:
            if node.addr <= addr < node.addr + node.size:
                return node
        return None
    for node in nodes:
        if node.addr == addr:
            return node
    return None

# %%
def getsuccessors(graph, node):
    return list(graph.successors(node))

# %%
def haslog(succs):
    for succ in succs:
        if isinstance(succ, Function):
            if succ.name == '__afl_maybe_log':
                return True
    return False

# %%
def isIdinsn(insn):
    if insn.mnemonic != 'mov':
        return False
    if len(insn.operands) != 2:
        return False
    if insn.operands[0].type != X86_OP_REG:
        return False
    if insn.reg_name(insn.operands[0].value.reg) != 'rcx':
        return False
    if insn.operands[1].type != X86_OP_IMM:
        return False
    return True

def getId(block):
    for insn in reversed(block.capstone.insns):
        if isIdinsn(insn):
            return insn.operands[1].value.imm
    return 0

# %%
startAddr = main.rebased_addr
endAddr = 0x41a5e6

# %%
block_ids = dict()
edge_ids = dict()
def parse(graph, addr, prev_id, visit):
    if addr in visit:
        return
    visit.append(addr)
    cur_node = get_node(graph, addr)
    if isinstance(cur_node, Function):
        return
    succs = getsuccessors(graph, cur_node)
    if haslog(succs):
        block = proj.factory.block(cur_node.addr)
        cur_id = getId(block)
        block_ids[addr] = cur_id
        edge_ids[(prev_id, cur_id)] = (prev_id >> 1) ^ cur_id
        print("%x: %x -> %x Edge ID: %d" % (addr, prev_id, cur_id, (prev_id >> 1) ^ cur_id))
        for succ in succs:
            parse(graph, succ.addr, cur_id, visit)
    else:
        block_ids[addr] = prev_id
        for succ in succs:
            parse(graph, succ.addr, prev_id, visit)

# %%
visit = []
parse(graph, main.rebased_addr, 0, visit)
# Out:
# 400800: 0 -> f459 Edge ID: 62553
# 400867: f459 -> f9c9 Edge ID: 33765
# 4008ba: f9c9 -> e493 Edge ID: 39031
# 402411: e493 -> faa Edge ID: 32227
# 4027fb: e493 -> 6343 Edge ID: 4362
# 402839: 6343 -> 9e2e Edge ID: 44943
# 40091f: e493 -> 11a0 Edge ID: 25577
# 400962: 11a0 -> ebdf Edge ID: 58127
# 4009a7: ebdf -> 25cf Edge ID: 20512
# 4009eb: 25cf -> 1439 Edge ID: 1758
# 400a2f: 1439 -> 8da7 Edge ID: 34747
# 400a73: 8da7 -> 2fb1 Edge ID: 26978
# 400ab7: 2fb1 -> b5e9 Edge ID: 41521
# 400afb: b5e9 -> fd68 Edge ID: 42908
# 400b3f: fd68 -> 57e Edge ID: 31690
# 400b83: 57e -> 147 Edge ID: 1016
# 400bc7: 147 -> fba0 Edge ID: 64259
# 400c0b: fba0 -> 902b Edge ID: 60923
# 400c4f: 902b -> 8218 Edge ID: 51725
# 400c93: 8218 -> c993 Edge ID: 34975
# 400cd7: c993 -> 48a4 Edge ID: 11373
# 400d1b: 48a4 -> adb7 Edge ID: 35301
# 400d5f: adb7 -> 9568 Edge ID: 50099
# 400da3: 9568 -> 2f2b Edge ID: 26015
# 400de7: 2f2b -> 5f80 Edge ID: 18453
# 40306f: 5f80 -> 109b Edge ID: 16219
# 400e2b: 5f80 -> f038 Edge ID: 57336
# 400e6f: f038 -> 82c6 Edge ID: 64218
# 402fdf: 82c6 -> 1ae6 Edge ID: 23429
# 400eb3: 82c6 -> 9240 Edge ID: 54051
# 400ef7: 9240 -> e3ec Edge ID: 43724
# 402e2f: e3ec -> f7dc Edge ID: 34346
# 400f3b: e3ec -> c7bc Edge ID: 46666
# 400f7f: c7bc -> b852 Edge ID: 56204
# 402d9f: b852 -> f209 Edge ID: 44576
# 400fc3: b852 -> 14ab Edge ID: 18562
# 4036e7: fd2f -> 9ca3 Edge ID: 57908
# 403777: 64eb -> abe4 Edge ID: 39313
# 403807: 62b7 -> ced2 Edge ID: 65417
# 403897: 8ff2 -> 7c0 Edge ID: 16441
# 403927: b612 -> 6070 Edge ID: 15225
# 4039b7: 2606 -> db08 Edge ID: 51211
# 403a47: a6d6 -> f590 Edge ID: 42747
# 403ad7: 5cf3 -> 8ae2 Edge ID: 42139
# 403b67: 4a1f -> d9d0 Edge ID: 64735
# 403bf7: fab1 -> a947 Edge ID: 54303
# 403c87: dbce -> fb56 Edge ID: 38577
# 403d17: b923 -> 6202 Edge ID: 16019
# 403da7: 8113 -> 2794 Edge ID: 26397
# 403e37: 13a5 -> 737f Edge ID: 31405
# 403ec7: 6a91 -> 105e Edge ID: 9494
# 403f57: ced4 -> fb8 Edge ID: 26834
# 403fe7: bec6 -> 4c9 Edge ID: 23466
# 404077: fa4c -> a765 Edge ID: 55875
# 402a87: 40a5 -> b89f Edge ID: 39117
# 402b17: e14e -> efbb Edge ID: 40732
# 402ba7: cc45 -> 963e Edge ID: 61468
# 402c37: acaf -> 3d3c Edge ID: 27499
# 402cc7: 18f3 -> 5171 Edge ID: 23816
# 402d57: 14ab -> b3c4 Edge ID: 47505
# 402de7: c7bc -> 853f Edge ID: 59105
# 402e77: 9240 -> 68f8 Edge ID: 8664
# 403027: f038 -> eff8 Edge ID: 38884
# 4030b7: 2f2b -> 74aa Edge ID: 25407
# 4028cb: 9568 -> 7359 Edge ID: 14829
# 402913: adb7 -> 84d6 Edge ID: 53773
# 402883: 48a4 -> 87c Edge ID: 11310
# 4027b3: 8218 -> 7ac1 Edge ID: 15309
# 40276b: 902b -> 46ce Edge ID: 3803
# 402723: fba0 -> f2a Edge ID: 29434
# 4026db: 147 -> d830 Edge ID: 55443
# 402693: 57e -> 4857 Edge ID: 19176
# 40264b: fd68 -> 3d80 Edge ID: 17204
# 402603: b5e9 -> 644d Edge ID: 16057
# 4025bb: 2fb1 -> e2a Edge ID: 6642
# 402573: 8da7 -> 3e1e Edge ID: 30925
# 40252b: 1439 -> 7464 Edge ID: 32376
# 40249b: 25cf -> e7c4 Edge ID: 62755
# 4024e3: ebdf -> b9e6 Edge ID: 52233
# 402452: 11a0 -> 8d94 Edge ID: 34116

# %%
sort_addr = sorted(block_ids.keys())

# %%
def getBlockid(addr):
    prev_addr = 0
    for each in sort_addr:
        if each > addr:
            break
        prev_addr = each
    return block_ids[prev_addr]

# %%
def getEdgeid(fromAddr, toAddr):
    from_id = getBlockid(fromAddr)
    if from_id == 0:
        print("invalid addr 0x%x" % fromAddr)
        return 0
    to_id = getBlockid(toAddr)
    if to_id == 0:
        print("invalid addr 0x%x" % toAddr)
        return 0
    if from_id == to_id:
        print("they are in the same block! %x-%x" % (fromAddr, toAddr))
        return 0
    if (from_id, to_id) in edge_ids:
        print("Found edge from %x to %x" % (from_id, to_id))
        return edge_ids[(from_id, to_id)]
    else:
        print("Error: can not find the tuple (%x, %x)" % (from_id, to_id))
    return 0

# %%
(getEdgeid(0x402b82, 0x4118c4))
# Out:
# Error: can not find the tuple (6a0, 4966)
# 0

# %%
((0xebe2 >> 1) ^ 0x2639)
# Out:
# 21448

# %%
chr(0x62)
# Out:
# 'b'
